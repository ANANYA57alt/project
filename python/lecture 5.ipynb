# %%
number=int(input("Enter a number: "))
is prime= True
if number>1:
  for i in range(2,int (number**0.5)+1):
    if number%i==0;

# %%
import random
number_to_guess=random.randint(1, 100)
guess=None

while guess !=number_to_guess:
  guess=int(input("guess number between 1 and 100: "))
  if guess<number_to_guess:
    print("too low!")
    elif guess>number_to_guess:
      print("too high!")
      print("congratulations! you've guessed the number")
# Out:
#   File "<ipython-input-3-04747b2b9c17>", line 9
#     elif guess>number_to_guess:
#     ^
# SyntaxError: invalid syntax

# %%
string= input("enter a string: ")
char=input("enter the character to count: ")
count= string.count(char)
print(f"the character'{char}'appears{count}times in the string")
# Out:
# enter a string: de
# enter the character to count: 4
# the character'4'appears0times in the string

# %%
string= input("enter a string: ")
if string==string[::-1]:
  print(f"{string}is a palindrom.")
  else:
    print("{string}is not a palimndrome")
# Out:
#   File "<ipython-input-5-42d33bc2d9aa>", line 4
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
string= input("enter a string: ")
if string==string[::-1]:
  print(f"{string}is a palindrom.")
  else:
    print("{string}is not a palimndrome")
# Out:
#   File "<ipython-input-5-42d33bc2d9aa>", line 4
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
for i in range(1, 6):
  for j in range(1, i+1):
    print("*", end = " ")
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
